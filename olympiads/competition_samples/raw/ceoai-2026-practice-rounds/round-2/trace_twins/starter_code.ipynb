# %% [markdown]
# # Trace Twins — BASELINE notebook
#
# Run top to bottom. Replace the `Submission` below's `score_A`/`score_B` with your real methods**, then build and submit `submission.pkl`.

# %% [markdown]
# ### 1. Setup (unzip the train data)

# %%
def print_dir(obj):
    for i in dir(obj):
        if i.startswith("_"):
            continue
        print(i)

# %%
# The train data is in this notebook's folder as train_data.zip — unzip it.
from pathlib import Path
from zipfile import ZipFile

archive = Path("train_data.zip")
if archive.exists():
    with ZipFile(archive) as zf:
        zf.extractall("data")
else:
    print("train_data.zip not found; using data/public_traces.csv")
# Out:
# train_data.zip not found; using data/public_traces.csv

# %% [markdown]
# ### 2. Your `Submission` (edit `score_A`/`score_B`)

# %%
import io, pickle
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec

class Submission:
    def __init__(self):
        # Load or train your models here. The baseline currently needs nothing.
        ...

    # ===== DO NOT EDIT: the cloud calls this to collect your scores =====
    def __call__(self, data: bytes) -> bytes:
        req = pickle.loads(data)
        fn = self.score_A if req["part"] == "A" else self.score_B
        scores = fn(req["windows"], req["pairs"])
        buf = io.BytesIO(); np.save(buf, np.asarray(list(scores), dtype=np.float64))
        return buf.getvalue()
    # ===================================================================

    def score_A(self, windows, pairs):
        # Part A (real names): placeholder (AUC 0.5 -> 0 pts). REPLACE with a real method.
        tfidf = TfidfVectorizer()
        corpus = []
        for i in windows:
            corpus.append(" ".join(i))
        x = tfidf.fit_transform(corpus).toarray()
        sims = []
        for i, j in pairs:
            emb1 = x[i]
            emb2 = x[j]
            sims.append(emb1@emb2)
        return sims

    def score_B(self, windows, pairs):
        corpus = []
        for i in windows:
            corpus.append(" ".join(i))
        print(corpus[0])
        return [0.0 for _ in pairs]

# %% [markdown]
# ### 3. Train your solution (run once)

# %%
sol = Submission()   # loads/trains everything

# %% [markdown]
# ### 4. (optional) Estimate your score locally

# %%
# OPTIONAL local check — self-contained; mirrors the grader (disjoint Part A / Part B
# programs, per-window scramble for B, 50+50 bands). Needs only public_traces.csv.
import csv, random
import numpy as np
from collections import defaultdict
from sklearn.metrics import roc_auc_score

WINDOW = 200; WPP = 8
def _load(p):
    out=[]
    with open(p) as f:
        r=csv.reader(f); next(r)
        for pid,cat,toks in r: out.append({"program_id":pid,"category":cat,"tokens":toks.split()})
    return out
def _windows(traces):
    out=[]
    for tr in traces:
        s=tr["tokens"]; n=(len(s)//WINDOW)*WINDOW
        out.extend([{"program_id":tr["program_id"],"category":tr["category"],"wid":j//WINDOW,
                     "tokens":s[j:j+WINDOW]} for j in range(0,n,WINDOW)][:WPP])
    return out
def _pairs(ws,n,seed):
    rng=random.Random(seed); bc=defaultdict(list); bp=defaultdict(list)
    for k,w in enumerate(ws): bc[w["category"]].append(k); bp[w["program_id"]].append(k)
    cats=sorted(bc); multi=[p for p in bp if len(bp[p])>=2]; P=[]; L=[]
    while len(P)<n:
        if rng.random()<0.5:
            p=rng.choice(multi); a,b=rng.sample(bp[p],2); P.append((a,b)); L.append(1)
        else:
            pool=bc[rng.choice(cats)]
            for _ in range(50):
                a,b=rng.sample(pool,2)
                if ws[a]["program_id"]!=ws[b]["program_id"]: P.append((a,b)); L.append(0); break
    return P,L
def _scramble(ws,off):
    vocab=sorted({t for w in ws for t in w["tokens"]}); out=[]
    for w in ws:
        r=random.Random(f'{w["program_id"]}:{w["wid"]}:{off}'); sh=list(vocab); r.shuffle(sh)
        m=dict(zip(vocab,sh)); out.append([m[t] for t in w["tokens"]])
    return out

tr=_load("data\\public_traces.csv")
by_prog={}
for t in tr: by_prog.setdefault(t["program_id"], t)
ids=sorted(by_prog); random.Random(7).shuffle(ids)
val=ids[:int(len(ids)*0.30)]; h=len(val)//2
wA=_windows([by_prog[i] for i in val[:h]]); WA=[w["tokens"] for w in wA]; pA,lA=_pairs(wA,3000,101)
wB=_windows([by_prog[i] for i in val[h:]]); WB=_scramble(wB,303); pB,lB=_pairs(wB,3000,202)
pts=lambda a,b: max(0.0, min(50.0,(a-0.5)/b*50.0))
aucA=roc_auc_score(lA, sol.score_A(WA,pA)); aucB=roc_auc_score(lB, sol.score_B(WB,pB))
print(f"Part A: AUC {aucA:.3f} -> {pts(aucA,0.34):.1f}/50")
print(f"Part B: AUC {aucB:.3f} -> {pts(aucB,0.28):.1f}/50")
print(f"ESTIMATED TOTAL ~ {pts(aucA,0.34)+pts(aucB,0.28):.1f}/100  (secret set differs slightly)")
# Out:
# delete_shadow scan_net exec_remote p26_b dns_query delete_shadow read_file dns_query open_socket scan_net delete_shadow scan_net read_file read_file read_file delete_shadow delete_shadow dns_query scan_net p26_b delete_shadow scan_net exec_remote read_file scan_net delete_shadow scan_net open_socket read_file dns_query delete_shadow open_socket scan_net dns_query exec_remote delete_shadow read_file dns_query scan_net read_file delete_shadow open_socket dns_query open_socket read_file delete_shadow dns_query scan_net exec_remote read_file delete_shadow read_file open_socket scan_net scan_net delete_shadow read_file dns_query read_file dns_query delete_shadow scan_net exec_remote exec_remote scan_net delete_shadow exec_remote p26_b open_socket exec_remote delete_shadow dns_query exec_remote exec_remote read_file delete_shadow exec_remote dns_query scan_net scan_net delete_shadow exec_remote delete_shadow delete_shadow exec_remote delete_shadow open_socket exec_remote exec_remote scan_net delete_shadow open_socket dns_query exec_remote exec_remote delete_shadow scan_net exec_remote dns_query delete_shadow delete_shadow scan_net open_socket exec_remote dns_query delete_shadow open_socket delete_shadow read_file exec_remote delete_shadow exec_remote dns_query exec_remote dns_query delete_shadow dns_query exec_remote p26_b p26_b delete_shadow open_socket dns_query exec_remote dns_query delete_shadow delete_shadow open_socket p26_b p26_b delete_shadow open_socket exec_remote scan_net exec_remote delete_shadow read_file exec_remote p26_b exec_remote delete_shadow dns_query scan_net dns_query open_socket delete_shadow exec_remote scan_net dns_query exec_remote delete_shadow p26_b open_socket scan_net delete_shadow delete_shadow p26_b open_socket open_socket scan_net delete_shadow dns_query p26_b read_file exec_remote delete_shadow read_file open_socket dns_query dns_query delete_shadow open_socket exec_remote exec_remote scan_net delete_shadow open_socket read_file exec_remote open_socket delete_shadow p26_b scan_net p26_b read_file delete_shadow scan_net dns_query read_file dns_query delete_shadow dns_query exec_remote read_file read_file delete_shadow p26_b p26_b scan_net exec_remote
# Part A: AUC 1.000 -> 50.0/50
# Part B: AUC 0.500 -> 0.0/50
# ESTIMATED TOTAL ~ 50.0/100  (secret set differs slightly)

# %% [markdown]
# ### 5. Build submission.pkl  (run LAST)

# %%
# Build submission.pkl  (this is what you upload as the Output)
import cloudpickle, os
# `sol` was trained above. Re-run the train cell first if you restarted the kernel.
with open("submission.pkl", "wb") as f:
    cloudpickle.dump(sol, f)          
mb = os.path.getsize("submission.pkl") / 1e6
print(f"wrote submission.pkl  ({mb:.1f} MB)  -- must be < 50 MB")
assert mb < 50, "too big: cap model size (fewer trees / depth)"
# Out:
# wrote submission.pkl  (0.0 MB)  -- must be < 50 MB
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### 6. Submit
# Click the **🦆 Submit to Judge** button in the toolbar and choose `submission.pkl` as the Output.
