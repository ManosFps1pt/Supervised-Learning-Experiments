# %%
import pandas as pd
from pathlib import Path

# %%
root_path = Path.cwd().parent / "data" / "essay-gap"

# %% [markdown]
# # Dataset

# %%
train_df = pd.read_csv(root_path / "train.csv")
train_df["before"][0], train_df["after"][0]
# Out:
# ('The life cycle of a Christmas tree from the seed to a 2-metre (7 ft) tree takes, depending on species and treatment in cultivation, between eight and twelve years. First, the seed is extracted from cones harvested from older trees. These seeds are then usually grown in nurseries and then sold to Christmas tree farms at an age of three to four years.',
#  'One issue that farmers face is the destruction of pine trees by pests, such as T. piniperda.')

# %% [markdown]
# # Submission

# %%
test_df = pd.read_csv(f"{root_path}/test.csv")

# %%
submission = pd.DataFrame({"sampleID": test_df["sampleID"], "answer": 0})
submission.head()
# Out:
#    sampleID  answer
# 0       100       0
# 1       101       0
# 2       102       0
# 3       103       0
# 4       104       0

# %%
submission.to_csv(Path.cwd().parent / "submission.csv", index=False)
